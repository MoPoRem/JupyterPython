# %% [markdown]
# # Python Introduction Course
# ## Welcome to session 1

# %% [markdown]
# ### To start:
# - Download Python 3.10:

# %% [markdown]
# ![image.png](attachment:23a19c40-536d-4cf9-b1a5-954d024341df.png)

# %% [markdown]
# - Check "Add Python 3.10 to PATH"

# %% [markdown]
# ![image.png](attachment:37f22166-b703-4bb2-8564-c6adb587c2a1.png)

# %% [markdown]
# - Press "Windows + R"
# - Type "py" and press enter

# %% [markdown]
# ### Hello, World!

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### Variables

# %%
a = 1
print(a)
print(a + 1)
print(a)
# Out:
# 1
# 2
# 1

# %%
a = 2
print(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d6c43fcb8b82> in <module>
#       1 a = 2
# ----> 2 print(A)
#
# NameError: name 'A' is not defined

# %%
a = 10
print(a / 3)
print(a // 3)
# Out:
# 3.3333333333333335
# 3

# %%
a = 3
b = 5
print(a + b * 2)
print((a + b) * 2)
# Out:
# 13
# 16
